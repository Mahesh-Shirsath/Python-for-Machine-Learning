# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
n = np.array([0,1,2,3,4,5])

# %%
xx = np.linspace(-0.75, 1., 100)

# %%
fig, axes = plt.subplots(1, 4, figsize=(12,4))

axes[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
axes[0].set_title('Scatter')

axes[1].step(n, n**2, lw=2)
axes[1].set_title('Step')

axes[2].bar(n, n**2, align='center', width=0.5, alpha=0.5)
axes[2].set_title('Bar Graph')

axes[3].fill_between(n, n**2, n**3, color='red', alpha=0.5)
axes[3].set_title('Fill Between')
# Out:
# Text(0.5, 1.0, 'Fill Between')

# %%
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)

ax.text(0.1, 0.2, r"$y=m^2$", fontsize=15, color='blue')
ax.text(0.6, 0.1, r"$y=m^3$", fontsize=15, color='orange')
# Out:
# Text(0.6, 0.1, '$y=m^3$')

# %%
fig, ax = plt.subplots(2, 3)
fig.tight_layout()

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax3 = plt.subplot2grid((3,3), (1,2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2,0))
ax5 = plt.subplot2grid((3,3), (2,1))
plt.tight_layout()

# %%
import matplotlib.gridspec as gridspec

# %%
fig = plt.figure()

gs = gridspec.GridSpec(2, 4, height_ratios=[2,1], width_ratios=[1,2,1,3])
for g in gs:
    ax = fig.add_subplot(g)
    
fig.tight_layout()

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((3,7), (0,0), colspan=1, rowspan=2)
ax2 = plt.subplot2grid((3,7), (2,0), colspan=1)
ax3 = plt.subplot2grid((3,7), (0,1), colspan=2, rowspan=2)
ax4 = plt.subplot2grid((3,7), (2,1), colspan=2)
ax5 = plt.subplot2grid((3,7), (0,3), colspan=1, rowspan=2)
ax6 = plt.subplot2grid((3,7), (2,3), colspan=1)
ax7 = plt.subplot2grid((3,7), (0,4), colspan=3, rowspan=2)
ax8 = plt.subplot2grid((3,7), (2,4), colspan=3)
plt.tight_layout()
# Same output as above

# %%
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)
fig.tight_layout()

inset_ax = fig.add_axes([0.23, 0.55, 0.35, 0.35]) # X, Y, width, height

inset_ax.plot(xx, xx**2, xx, xx**3)
inset_ax.set_title('zoom near origin')

inset_ax.set_xlim(-.2, .2)
inset_ax.set_ylim(-.005, .01)

inset_ax.set_yticks([0, 0.005, 0.01])
inset_ax.set_xticks([-0.1,0,.1]);
